# %% [markdown]
# # ¡Hola Miltón! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima. Si en algún punto tienes comentarios, siéntete libre de dejarlos también. Al final del notebook, te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**
#
#
# Encontrarás mis comentarios dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso.:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# # Contenido<a id='back'></a>
#
# ---
#
# <div style='background-color:lightyellow; padding:15px;'>
#
#
#  * [**DESCRIPCIÓN DEL PROYECTO**](#'intro')
#
#
#  * [**ETAPA 1:** Abre y examina el archivo de datos. ](#dataset)
#
#      - [DataFrame del Proyecto](#df)
#
#      - [Librerías del Proyecto](#lib)
#
#      - [Examinando los Datos](#examinar)
#
#      - [Examinando los Datos Graficamente](#exagraf)
#
#
#  * [**ETAPA 2:** Segmentación de Datos  (Entrenamiento, Validación y Prueba](#segmenta)
#
#      - [Definición de las Características y Objetivos](#Xy)
#
#      - [Segmentación del Dataset y Creación de Conjuntos de Datos](#split)
#
#
#  * [**ETAPA 3:** Entrenamiento de Modelos de Clasificación y Evaluación de la Calidad](#train)
#
#      - [Árboles de Decisión - *Hiperparámetros (Valores por Defecto)*](#dt1)
#
#      - [Árboles de Decisión - *Hiperparámetro (max_depth)*](#dt2)
#
#      - [Árboles de Decisión - *Hiperparámetro (min_samples_split)*](#dt3)
#
#      - [Árboles de Decisión - *Hiperparámetro (min_samples_leaf)*](#dt4)
#
#      - [Árboles de Decisión - *Hiperparámetro (max_features)*](#dt5)
#
#      - [Árboles de Decisión - *Hiperparámetro (criterion)*](#dt6)
#
#      - [Árboles de Decisión - *Hiperparámetros (Bucles FOR Anidados)*](#dt7)
#
#      - [Bosques Aleatorios  - *Hiperparámetros (Valores por Defecto)*](#rf1)
#
#      - [Bosques Aleatorios  - *Hiperparámetros (Bucles FOR Anidados)*](#rf2)
#
#
#  * [**ETAPA 4:** Comparación de Resultados entre Modelos Evaluados (*Conjunto de Prueba*)](#best)
#
#      - [Calidad del Modelo 'DecisionTreeClassifier' con Hiperparámetros Finales](#dt_best)
#
#      - [Calidad del Modelo 'RandomForestClassifier' con Hiperparámetros Finales](#rf_best)
#
#      - [Selección del Mejor Modelo Entrenado](#res_best)
#
#
#  * [**ETAPA 5:** Prueba de Cordura](#cordura_title)
#
#     - [Generalidades de las Pruebas de Cordura](#cordura_1)
#
#     - [Implementación del Modelo Trivial (*Prueba de Cordura con Predicción Constante*)](#cordura2)
#
#     - [Entrenamiento con Etiquetas Aleatorizadas](#cordura3)
#
#     - [Comprobación de la Consistencia de las Características](#cordura4)
#
#     - [Predicción con Datos Vacíos o Características Sin Sentido](#cordura5)
#
#     - [Validación Cruzada](#cordura6)
#
#
#
#  * [**ETAPA 6:** Comentarios Finales del Proyecto](#end)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Genial tu uso de la tabla de contenido 💥
# </div>

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ## DESCRIPCIÓN DEL PROYECTO<a id='intro'></a>
#
# </span>

# %% [markdown]
# La compañía móvil **Megaline** no está satisfecha al ver que muchos de sus clientes utilizan planes heredados. Quieren desarrollar un modelo que pueda analizar el comportamiento de los clientes y recomendar uno de los nuevos planes de Megaline: `Smart` o `Ultra`.
#
# Tienes acceso a los datos de comportamiento de los suscriptores que ya se han cambiado a los planes nuevos (*del proyecto del sprint de Análisis estadístico de datos*). Para esta **tarea de clasificación** debes crear un modelo que escoja el plan correcto. Como ya hiciste el paso de procesar los datos, puedes lanzarte directo a crear el modelo.
#
# Desarrolla un modelo con la mayor exactitud posible. En este proyecto, el **`umbral de exactitud es 0.75`**. Usa el dataset para comprobar la exactitud.
#
# ---
#
#
# Cada observación en el dataset contiene información del comportamiento mensual sobre un usuario. La información dada es la siguiente:
#
#  * `сalls` — número de llamadas.
#
#  * `minutes` — duración total de la llamada en minutos.
#
#  * `messages` — número de mensajes de texto.
#
#  * `mb_used` — Tráfico de Internet utilizado en MB.
#
#  * `is_ultra` — plan para el mes actual (Ultra - 1, Smart - 0).
#
#
#
# Los criterios de evaluación definidos para este proyecto son los que se detallan a continuación:
#
# ---
#
# <div style='background-color:lightgray; padding:15px'>
#
#
#  * **¿Cómo leíste los datos después de descargarlos?**
#
#
#  * **¿Segmentaste correctamente los datos en `conjuntos de entrenamiento`, `validación` y `prueba`?**
#
#
#  * **¿Cómo escogiste el tamaño de los conjuntos?**
#
#
#  * **¿Evaluaste correctamente la calidad del modelo?**
#
#
#  * **¿Qué modelos e hiperparámentros usaste?**
#
#
#  * **¿Cuáles fueron tus hallazgos?**
#
#
#  * **¿Probaste los modelos correctamente?**
#
#
#  * **¿Cuál es tu puntuación de exactitud?**
#
#
#  * **¿Te ceñiste a la estructura del proyecto y mantuviste limpio el código?**
#
#
#
# </div>

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ## ETAPA 1: Abre y examina el archivo de datos<a id=dataset></a>
#
# </span>

# %% [markdown]
# <span style='color:blue'>
#
# ### Librerías del Proyecto<a id='lib'></a>
#
# </span>

# %%
# Primeramente importaré  las librerías que utilizaré en este proyecto
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <span style='color:blue'>
#
# ### DataFrame del Proyecto<a id='df'></a>
#
# </span>

# %%
# importamos el archivo del proyecto al DataFrame "df"
df = pd.read_csv('datasets/users_behavior.csv')
df.head()
# Out:
#    calls  minutes  messages   mb_used  is_ultra
# 0   40.0   311.90      83.0  19915.42         0
# 1   85.0   516.75      56.0  22696.96         0
# 2   77.0   467.66      86.0  21060.45         0
# 3  106.0   745.53      81.0   8437.39         1
# 4   66.0   418.74       1.0  14502.75         0

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ### Examinando los Datos<a id='examinar'></a>
#
# </span>

# %%
#  A continuación revisaré los tipos de datos que contiene cada columna, además de ver si es que existen datos nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3214 entries, 0 to 3213
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   calls     3214 non-null   float64
#  1   minutes   3214 non-null   float64
#  2   messages  3214 non-null   float64
#  3   mb_used   3214 non-null   float64
#  4   is_ultra  3214 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 125.7 KB

# %%
# Según los datos obtenidos no existen datos ausentes, esto podemos validarlo de la siguiente manera
df.isna().sum()
# Out:
# calls       0
# minutes     0
# messages    0
# mb_used     0
# is_ultra    0
# dtype: int64

# %%
# Seguidamente revisare si es que existen datos duplicados en el dataset del proyecto

df[df.duplicated() == True].count()
# Out:
# calls       0
# minutes     0
# messages    0
# mb_used     0
# is_ultra    0
# dtype: int64

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ### Examinando los Datos Gráficamente <a id='exagraf'></a>
#
# </span>

# %% [markdown]
# A continuación realizaré un histograma para poder entender mejor la distribución de las características numéricas de los datos de las columnas `calls`, `minutes`, `messages` y `mb_used`, con la finalidad de poder identificar si los datos están sesgados.

# %%
df.hist(bins=50, figsize=(11, 7))
plt.show()

# %%
amount  = df['is_ultra'].value_counts()
amount
# Out:
# 0    2229
# 1     985
# Name: is_ultra, dtype: int64

# %% [markdown]
# La única característica que llama un poco la atención es la de la columna de datos `messages`, ya que parece que sus datos estan muy sesgados hacia la izquierda, lo cual probablemente sea debido a que no son muchos los usuarios que envían mensajes.
#
# Por otro lado también se puede apreciar que 2229  clientes (*aproximadamente el 69.4%*) que tiene la compañía móvil Megaline se encuentran en el plan `Smart` y los restantes 985 (*aproximadamente el 30.6%*) se encuentran en el plan `Ultra`.
#
# ---
#
# A continuación realizaré un par de gráficas de Boxplot en Seaborn, para detectar valores atípicos en cada columna.

# %%
plt.figure(figsize=(10, 5))
for i, column in enumerate(df.columns[:-1], 1):  # Ignora la columna 'is_ultra'
    plt.subplot(2, 2, i)
    sns.boxplot(df[column])
    plt.title(f"Boxplot de {column}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# A continuación realizaré una gráfica del tipo `pairplot` en Seaborn, con la finalidad de poder apreciar como se agrupan los datos de las cuatro columnas de nuestro dataset, pero en función a la variable `is_ultra`. Veamos que obtenemos...
#
# ---

# %%
sns.pairplot(df, hue='is_ultra', palette="coolwarm")
plt.show()

# %% [markdown]
# ---
#
# Finalmente en lo que concierne a esta parte del proyecto, realizaré una gráfica más la cual es una Matriz de Correlación, la cual la generaré debido a que **deseo poder identificar si es que existen relaciones entre las diferentes columnas o variables del dataset del proyecto**. Según la bibliografía que he revisado he podido encontrar que esta gráfica podría ser de ayuda para cuando este trabajando con el álgoritmo de regresión.

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(9, 3))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Matriz de Correlación - Heatmap")
plt.show()

# %% [markdown]
#
# ---
# <div style='background-color:lightblue; padding:15px;'><span style='color:darkblue'>
#
# (**Comentarios del Alumno - Milton Valle**)
#
# Seguidamente a la lectura del archivo CSV, `users_behaviour.csv`, se ha podido ver que:
#
# **EXAMINANDO DATOS**
#
#  1. Todas las columnas de datos presentan un tipo de dato que va en concordancia con el tipo de información que se presenta:
#
#     * Columna `calls`: Tipo flotante (*float64*)
#     * Columna `minutes`: Tipo flotante (*float64*)
#     * Columna `messages`: Tipo flotante (*float64*)
#     * Columna `mb_used`: Tipo flotante (*float64*)
#     * Columna `is_ultra`: Tipo entero (*int64*)
#
#
#  2. No se ha identificado la existencia de **valores ausentes** en el presente DataFrame del proyecto.
#
#
#  3. No se ha identificado la existencia de **columnas con valores duplicados** en el DataFrame.
#
#
# **EXAMINANDO DATOS GRÁFICAMENTE**
#
#
#  4. Con ayuda de los **histogramas** para cada una de las columnas numéricas de nuestro DataFrame, se ha podido identificar:
#
#     a. La columna de datos `messages` presenta  un sesgo bien marcado hacia la izquierda, lo cual se deba posiblemente a que pocos clientes mandan mensajes.
#
#     b. Un 69.4% del total de clientes que tiene la compañía `Megaline` se encuentran registrados en el plan `Smart`. El restante 30.6% de los clientes pertenece al plan `Ultra`.
#
#
#  5. La gráfica de **Boxplot** me ha ayudado a poder identificar que existen valores atípicos bien marcados, principalmente en los datos de las columnas `minutes` y `mb_used`.  **Es importante haber detectado esta característica principalmente para la utilziacion del algoritmo de regresión, ya que este presenta una mayor sensibilidad a este tipo de característica en los datos**.
#
#
#  6. En lo concerniente a las gráficas **pairplots** de Seaborn se a podido apreciar en el agrupamiento de los datos de las columnas numéricas, con respecto a la columna `is_ultra`, que en cada una de las gráficas propias de cada fila, siempre tienen un mayor peso (*para cada columna*) los usuarios del plan `Smart`, esto se debe a la gran cantidad de usuarios que existe en este plan.
#
#
#  7. Finalmente con la **Matriz de Correlación** he podido ver que:
#
#     a. Existe una **correlación muy fuerte** entre las columnas `minutes` y `calls`.
#
#     b. Existe una **correlación moderada** entre las columnas `minutes` con `mb_used` y entre las columnas `calls` y `mb_used`.
#
#     c. Finalmente es importante notar que los datos de la columna `is_ultra` tiene una correlación más alta con las variables `calls` y `minutes`, siendo que estas dos últimas también se encuentran fuertemente correlacionadas entre sí.
#
#
# **`A partir de lo presentado puedo afirmar que ahora estamos en condiciones de pasar a la siguiente etapa de trabajo de este proyecto, debido a que se ha podido examinar y comprender mejor a los datos de cada columna de nuestro DataFrame del proyecto`**.
#
#
#
# </span></div>
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Milton debo felicitarte por tu análisis exploratorio de datos. Está muy completo y bien estructurado, has encontrado información valiosa, que te servirá para establecer la estrageía más adecuada en las siguientes etapas de un proyecto.
#
# Permiteme complementar tu EDA con aspectos que seguramente te serviran en próximos proyectos.
#
# - El uso del `boxplot` es una primera forma para indentificar datos atípicos, aunque si queremos ser más rigurosos podemos usar una metolodología basada en el [Z-Score](https://www.machinelearningplus.com/machine-learning/how-to-detect-outliers-with-z-score/) para comprobar cuáles datos son estadísticamente atípicos, para luego hacer una comparativa de los modelos con y sin datos atípicos.
# - La matriz de correlación es una gran herramienta para identificar la relaciones entre columnas. Realmente hay que fijarnos de las relaciones superiores a 0.8 o -0.8. Recuerda incluir tu interpretación sobre las relaciones fuertes. En este caso una relación entre `calls` y `minutes` tiene sentido, ya que son proporcionales, entre más llamadas un usuario haga, mayor será el número de minutos consumidos.
#
#
# <img src="https://www.researchgate.net/publication/299402589/figure/tbl1/AS:669067656572937@1536529568883/Meaning-of-Pearson-correlation-coefficient-value-r.png" alt="drawing" width="400"/>
# </div>

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ## ETAPA 2: Segmentación de Datos (Entrenamiento, Validación y Prueba)<a id=segmenta></a>
#
# </span>

# %% [markdown]
# ---
#
# Para realizar la segmentación de los datos en Conjunto de Entrenamiento, Conjunto de Prueba y Conjunto de Validación. Realizaré la división de todo el dataset en 60% para el Conjunto de Entrenamiento, 20% para el Conjunto de Prueba y otro 20% para el Conjunto de Validación; sumando en total el 100% de todo el dataset.
#
# ---

# %%
# Utilizaré la función "train_test_split", para dividir el dataset del proyecto
from sklearn.model_selection import train_test_split

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Es una buena práctica importar todas la librerías y funciones en una única celda al inicio del notebook.
# </div>

# %% [markdown]
# <span style='color:blue'>
#
# ### Definición de las Características y Objetivos<a id='Xy'></a>
#
# </span>

# %%
# Utilizaré las siglas universales para separar el dataset en un dataset de caracteristicas (X) y otro dataset de objetivo (y)
X = df.drop(labels='is_ultra', axis=1)
y = df['is_ultra']

# %% [markdown]
# <span style='color:blue'>
#
# ### Segmentación del Dataset y Creación de Conjuntos de Datos<a id='split'></a>
#
# </span>

# %%
# primeramente asignaré un 60% del total del dataset al Conjunto de Entrenamiento y el restante 40% será un dataset provisional que utilizaré posteriormente.
X_train, X_temp, y_train, y_temp = train_test_split(X, y, random_state=12345, test_size=0.4)

# %%
# A continuación del 40% restante asignaré un 20% para el Conjunto de prueba y un 20% para el Conjunto de Validación
X_test, X_valid, y_test, y_valid = train_test_split(X_temp, y_temp, random_state=12345, test_size=0.5)

# %%
# Ahora presentaré la cantidad de datos que contiene cada Conjunto...

print(f"Conjunto de Entrenamiento={X_train.shape}   -   Conjunto de Prueba={X_test.shape}    -   Conjunto de Validación={X_valid.shape}")
# Out:
# Conjunto de Entrenamiento=(1928, 4)   -   Conjunto de Prueba=(643, 4)    -   Conjunto de Validación=(643, 4)

# %% [markdown]
# ---
#
# <div style='background-color:lightblue; padding:15px'><span style='color:darkblue'>
#
# (**Comentarios del Alumno - Milton Valle**)
#
# A partir de la ejecución de los últimos 4 comandas; Hemos segmentado los datos de la siguiente manera:
#
#  * `Conjunto de entrenamiento`: 1928 registros (**60% del total**).
#  * `Conjunto de validación`: 643 registros (**20% del total**).
#  * `Conjunto de prueba`: 643 registros (**20% del total**).
#
#     </span></div>
#
#  ---

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Muy buen trabajo haciendo la segmentación de los datos. El uso del conjunto de validación es especialmente importante cuando vamo a realizar una optimización de hiperpárametros.
# </div>

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ## ETAPA 3: Entrenamiento de Modelos de Clasificación y Evaluación de la Calidad<a id=train></a>
#
# </span>

# %% [markdown]
# <span style='color:blue'>
#
# ### Árboles de Decisión - Hiperparámetros (`Valores por Defecto`)<a id='dt1'></a>
#
# </span>

# %%
# Para esta primera parte de Entrenamiento y Evaluación de los modelos utilizaré el algoritmo "DecisionTreeClassifier"
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
# Defino un modelo del tipo de DecisionTreeClassifier
dt_model = DecisionTreeClassifier(random_state=12345)

# Entrenamos el modelo DecisionTreeClassifier con el conjunto de entrenamiento
dt_model.fit(X_train, y_train)

# Seguidamente realizo la evaluación del modelo, utilizando el Conjunto de Validación
y_val_pred_dt1 = dt_model.predict(X_valid)

accuracy1 = accuracy_score(y_valid, y_val_pred_dt1)

print(f"La precisión obtenida con los valores de los hiperparámetros por defecto es: {accuracy1:.4f}")
# Out:
# La precisión obtenida con los valores de los hiperparámetros por defecto es: 0.7309

# %% [markdown]
# ---
#
# <div style='background-color:lightblue; padding:15px;'><span style='color:darkblue'>
#
# **(Comentarios del alumno - Milton Valle)**
#
# En las siguientes líneas de código voy a ir buscando el mejor ajuste para cada hiperparámetro del modelo `DecisonTreeClassifier`, para lo cual utilizaré el siguiente orden de ajuste de los hiperparámetros:
#
#  1. `max_depth`
#  2. `min_samples_split`
#  3. `min_samples_leaf`
#  4. `max_features`
#  5. `criterion`
#
#  **He decidido como regla de análisis de la precisión para esta parte del proyecto, que a medida que en cuentre el ajuste óptimo para cada hiperparámetro, utilizaré el hiperparámetro encontrado en el ejercicio anterior con el ejercicio siguiente y con base a ese valor buscaré ajustar el siguiente hiperparámetro.**
#
#
# </span></div>
#
#  ---

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ### Árboles de Decisión - *Hiperparámetro (`max_depth`)*<a id='dt2'></a>
#
# </span>

# %%
# Ahora buscaré optimizar la precisión del modelo mediante el ajuste del hiperparámetro "max_depth"
best_accuracy = 0
best_depth = 0

for depth in range(1, 31):
    dt_model = DecisionTreeClassifier(max_depth=depth, random_state=12345)
    dt_model.fit(X_train, y_train)
    y_val_pred_dt2 = dt_model.predict(X_valid)
    accuracy2 = accuracy_score(y_valid, y_val_pred_dt2)
    
    if accuracy2 > best_accuracy:
        best_accuracy = accuracy2
        best_depth = depth
        
print(f"Mejor ajuste del hiperparámetro MAX_DEPTH={best_depth}   -   PRECISION={best_accuracy:.4f}")
# Out:
# Mejor ajuste del hiperparámetro MAX_DEPTH=7   -   PRECISION=0.7994

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ### Árboles de Decisión - *Hiperparámetro (`min_samples_split`)*<a id='dt3'></a>
#
# </span>

# %%
# Ajustaremos el hiperparámetro 'min_samples_split' y observaremos cómo afecta la precisión
best_accuracy_split = 0
best_split = 0

# Probar diferentes valores de min_samples_split
for split in range(2, 31):
    dt_model = DecisionTreeClassifier(max_depth=7, min_samples_split=split, random_state=12345)
    dt_model.fit(X_train, y_train)
    y_val_pred_dt3 = dt_model.predict(X_valid)
    accuracy3 = accuracy_score(y_valid, y_val_pred_dt3)
    
    if accuracy3 > best_accuracy_split:
        best_accuracy_split = accuracy3
        best_split = split

print(f"Mejor ajuste del hiperparámetro MIN_SAMPLES_SPLIT={best_split}   -   PRECISION={best_accuracy_split:.4f}")
# Out:
# Mejor ajuste del hiperparámetro MIN_SAMPLES_SPLIT=2   -   PRECISION=0.7994

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# ---
#
# <span style='color:blue'>
#
# ### Árboles de Decisión - *Hiperparámetro (`min_samples_leaf`)*<a id='dt4'></a>
#
# </span>

# %%
# Ahora vamos a ajustar el hiperparámetro 'min_samples_leaf'
best_accuracy_leaf = 0
best_leaf = 0

# Probar diferentes valores de min_samples_leaf
for leaf in range(1, 31):
    dt_model = DecisionTreeClassifier(max_depth=7, min_samples_split=2, min_samples_leaf=leaf, random_state=12345)
    dt_model.fit(X_train, y_train)
    y_val_pred_dt4 = dt_model.predict(X_valid)
    accuracy4 = accuracy_score(y_valid, y_val_pred_dt4)
    
    if accuracy4 > best_accuracy_leaf:
        best_accuracy_leaf = accuracy4
        best_leaf = leaf
        
print(f"Mejor ajuste del hiperparámetro MIN_SAMPLES_LEAF={best_leaf}   -   PRECISION={best_accuracy_leaf:.4f}")
# Out:
# Mejor ajuste del hiperparámetro MIN_SAMPLES_LEAF=3   -   PRECISION=0.8009

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# ---
#
# <span style='color:blue'>
#
# ### Árboles de Decisión - *Hiperparámetro (`max_features`)*<a id='dt5'></a>
#
# </span>

# %%
# Ahora buscare justar el hiperparámetro 'max_features' con el valor más óptimo
best_accuracy_features = 0
best_features = 0

# Probar diferentes valores de max_features (int y float fracción de características)
for features in range(1, X_train.shape[1] + 1):
    dt_model = DecisionTreeClassifier(max_depth=7, min_samples_split=2, min_samples_leaf=3, max_features=features, random_state=12345)
    dt_model.fit(X_train, y_train)
    y_val_pred_dt5 = dt_model.predict(X_valid)
    accuracy5 = accuracy_score(y_valid, y_val_pred_dt5)
    
    if accuracy5 > best_accuracy_features:
        best_accuracy_features = accuracy5
        best_features = features

print(f"Mejor ajuste del hiperparámetro MAX_FEATURES={best_features}   -   PRECISION={best_accuracy_features:.4f}")
# Out:
# Mejor ajuste del hiperparámetro MAX_FEATURES=4   -   PRECISION=0.8009

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# ---
#
#
# <span style='color:blue'>
#
# ### Árboles de Decisión - *Hiperparámetro (`criterion`)*<a id='dt6'></a>
#
# </span>

# %%
# Ajustar el hiperparámetro 'criterion' (gini vs entropy)
best_accuracy_criterion = 0
best_criterion = ''

# Probar los dos criterios disponibles: 'gini' y 'entropy'
for criterion in ['gini', 'entropy']:
    dt_model = DecisionTreeClassifier(max_depth=7, min_samples_split=2, min_samples_leaf=3, max_features=3, criterion=criterion, random_state=12345)
    dt_model.fit(X_train, y_train)
    y_val_pred_dt6 = dt_model.predict(X_valid)
    accuracy6 = accuracy_score(y_valid, y_val_pred_dt6)
    
    if accuracy6 > best_accuracy_criterion:
        best_accuracy_criterion = accuracy6
        best_criterion = criterion

print(f"Mejor ajuste del hiperparámetro CRITERION={best_criterion}   -   PRECISION={best_accuracy_criterion:.4f}")
# Out:
# Mejor ajuste del hiperparámetro CRITERION=gini   -   PRECISION=0.7978

# %% [markdown]
# <div style='background-color:orange; padding:15px'>
#
# **DUDA OCURRIDA DURANTE LA ELABORACIÓN DEL PROYECTO:**
#
# Me ha quedado la duda de si el modelo adquiere una mayor precisión si es que ajustamos sus hiperparámetros tal y como lo hemos hecho en los últimos 6 casos. O es que tal vez se podría llegar a una mayor precisión si utilizamos `cinco bucles FOR` y obtenemos todos los ajustes en una sola corrida de programa.
#
# Esta duda la resolveremos a partir de la siguiente ejecución del código, donde realizo los mismos pasos anteriores, pero con la ejecución de un sólo programa.
#
# </div>
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Milton tienes un magnífico dominio de la metodología de optimización de hiperparámetros.
#
# Respondiendo a tu duda, usar *for anidados* es una mejor estragegía porque permite comprobar varios los parámetros al tiempo. Aunque hay formas de hacerlo una manera más eficiente, usando liberias y funciones diseñandas especialmente pára la optimización de hiperparámetros. Acá te comparto información de algunas de estas:
#
# - [GridSearch y RandomSearch](https://machinelearningmastery.com/hyperparameter-optimization-with-random-search-and-grid-search/)
# - [Optuna](https://medium.com/data-and-beyond/master-the-power-of-optuna-a-step-by-step-guide-ed43500e9b95)
#
# La forma en como funcionan es similar, seleccionas los parámetros a optimizar, estableces los valores que quieras probar, y ya el código interno de cada función se encarga de encontrar la mejor combinación de parámetros. Básicamente hacer algo similar al *for anidado*, pero mucho **más eficiente, menos líneas de código y sobretodo mucho más rápido**. Revisa la info que te comparto, estoy seguro que te servirá para futuros proyectos.
# </div>

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# ---
#
#
# <span style='color:blue'>
#
# ### Árboles de Decisión - Hiperparámetros (`Bucles FOR Anidados`)<a id='dt7'></a>
#
# </span>

# %%
# Ajuste óptimo de hiperparámetros: "max_depth", "min_samples_split", "min_samples_leaf", "max_features" y "criterion"
best_accuracy_dt = 0
best_depth = 0
best_min_split = 0
best_min_leaf = 0
best_features = 0
best_criterion = ''

# Cinco bucles FOR para probar diferentes valores de "max_depth", "min_samples_split", "min_samples_leaf", "max_features" y "criterion"
for criteria in ['gini', 'entropy']:
    for features in range(1, X_train.shape[1] + 1):
        for leaf in range(1, 11, 1):
            for min_split in range(2, 11, 1):
                for depth in range(1, 11, 1):
                    dt_model = DecisionTreeClassifier(max_depth=depth, min_samples_split=min_split, 
                                                                                                      min_samples_leaf=leaf, max_features=features, random_state=12345)
                    dt_model.fit(X_train, y_train)
                    y_val_pred_dt7 = dt_model.predict(X_valid)
                    accuracy7 = accuracy_score(y_valid, y_val_pred_dt7)

                    if accuracy7 > best_accuracy_dt:
                        best_accuracy_dt = accuracy7
                        best_depth = depth
                        best_min_split = min_split
                        best_min_leaf = leaf
                        best_features = features
                        best_criterion = criteria
    
print(f'Se ha optinido una PRECISIÓN={best_accuracy_dt:.4f}')
print(f'MAX_DEPTH={best_depth} - MIN_SAMPLES_SPLIT={best_min_split} - MIN_SAMPLES_LEAF={best_min_leaf} - MAX_FEATURES={best_features} - CRITERION={best_criterion}')
# Out:
# Se ha optinido una PRECISIÓN=0.8072
# MAX_DEPTH=9 - MIN_SAMPLES_SPLIT=2 - MIN_SAMPLES_LEAF=6 - MAX_FEATURES=2 - CRITERION=gini

# %% [markdown]
# ---
#
# <div style='background-color:lightblue; padding:15px'><span style='color:darkblue'>
#
# (**Comentarios del Alumno - Milton Valle**)
#
#  - A partir de los primeros resultados obtenidos con el algoritmo **DecisionTreeClassifier**, se puede apreciar que **configurando los hiperparámetros uno por uno**  la **máxima precisión alcanzada ha sido de 0.8009**
#
#
#  - En cambio **utilizando varios bucles FOR, y dejando que la computadora interactue sola con los mismos cinco hiperparámetros** (*uno a la vez*), se ha logrado una pequeña mejora habiéndose alcanzado una **precisión de 0.8072**.
#
#
# **Siendo por lo tanto, estos últimos hiperparámetros los que llegaremos a modificar en el modelo cuanto evaluemos la precisión con el Conjunto de Prueba, en la siguiente etapa de este proyecto.**
#
#
# </span></div>
#
# ---
#
# | **NO**| **MODELO** | **HIPERPARAMETROS MODIFICADOS** | **PRECISION** | **OBJETIVO** | **CUMPLE** |
# |:--:|:-----:|:-------------------------:|:---------:|:--------:|:------:|
# | 1 | DecisionTreeClassifier | None | 0.7309 | >= 0.75 | NO |
# | 2 | DecisionTreeClassifier | max_depth=7 | 0.7994 | >= 0.75 | **SI** |
# | 3 | DecisionTreeClassifier | min_samples_split=2 (*default*) | 0.7994 | >=0.75 | **SI** |
# | 4 | DecisionTreeClassifier | min_samples_leaf=3 | 0.8009 | >=0.75 | **SI** |
# | 5 | DecisionTreeClassifier | max_features=3 | 0.8009 | >=0.75 | **SI** |
# | 6 | DecisionTreeClassifier | criterion='gini' | 0.7978 | >=0.75 | **SI** |
# | **7** | **DecisionTreeClassifier** | **max_depth=9, min_samples_split=2, min_samples_leaf=6, max_features=2, criterion='gini'** | **0.8072** | >=0.75 | **SI** |
#
# ---

# %% [markdown]
# ---
#
# <div style='background-color:orange; padding:15px'>
#
# **NOTA IMPORTANTE:**
#
# Con la experiencia obtenida en el anterior modelo (*DecisionTreeClassifier*), seguidamente para la evaluación del modelo **`RandomForestClassifier`**, ahora realizaremos únicamente dos entrenamientos del modelo:
#
#  - El primer modelo a entrenar con el algoritmo **`RandomForestClassifier`** será con los **valores por defecto de los Hiperparámetros**.
#
#
#  - El segundo modelo a entrenar con el algoritmo **`RandomForestClassifier`** será con **multiples bucles FOR, ajustando los hiperparámetros de este modelo con la ayuda de la computador**. Esto debido a que hemos podido constatar que con esta metodología de trabajo obtenemos una mayor precisión del modelo.
#
# </div>
#
# ---

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# ---
#
#
# <span style='color:blue'>
#
# ### Bosque Aleatorio - Hiperparámetros (`Valores por Defecto`)<a id='rf1'></a>
#
# </span>

# %%
# Primeramente importo el algoritmo RandomForestClassifier del modelo Ensemble, ya que es el algoritmo que utilizaré en esta parte del proyecto

from sklearn.ensemble import RandomForestClassifier

# %%
# Defino a RandomForestClassifier como el algoritmo que utilizaré
rf_model = RandomForestClassifier(random_state=12345)

# Entreno el modelo seleccionado con el Conjunto de Entrenamiento
rf_model.fit(X_train, y_train)

# Seguidamente realizo la evaluación del modelo, utilizando el Conjunto de Validación
y_val_pred_rf1 = rf_model.predict(X_valid)

# verifico la precisión que hemos obtenido
rf_accuracy1 = accuracy_score(y_valid, y_val_pred_rf1)

print(f"La precisión obtenida con los valores de los hiperparámetros por defecto es: {rf_accuracy1:.4f}")
# Out:
# La precisión obtenida con los valores de los hiperparámetros por defecto es: 0.7854

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# ---
#
# <span style='color:blue'>
#
# ### Bosque Aleatorio - Hiperparámetros (`Bucles FOR Anidados`)<a id='rf2'></a>
#
#
# </span>

# %% [markdown]
# <div style=background-color:red; padding:20px;>
#
# ---
#
# <span style='color:white'>
#
# **PRECAUSION: La siguiente celda de código tiene cinco bucles for anidados y toma aproximadamente 5 minutos en ejecutarse.**
#
# </span>
#
# ---
#
# </div>

# %%
# Ajuste óptimo de hiperparámetros: "n_estimators", "max_depth", "min_samples_split", "min_samples_leaf" y "criterion"
best_accuracy_rf = 0
best_estimator = 0
best_depth = 0
best_split = 0
best_leaf = 0
best_criterion = ''

# Doble bucle FOR para probar diferentes valores de "n_estimators" y "max_depth"
for criteria in ['gini', 'entropy']:
    for estimator in range(1, 21, 1):
        for depth in range(1, 21, 1):
            for min_split in range(2, 5, 1):
                for min_leaf in range(1, 5, 1):
                    rf_model = RandomForestClassifier(n_estimators=estimator, max_depth=depth, min_samples_split=min_split, 
                                                      min_samples_leaf=min_leaf, criterion=criteria, random_state=12345)
                    rf_model.fit(X_train, y_train)
                    y_val_pred_rf2 = rf_model.predict(X_valid)
                    rf_accuracy2 = accuracy_score(y_valid, y_val_pred_rf2)
                        
                    if rf_accuracy2 > best_accuracy_rf:
                        best_accuracy_rf = rf_accuracy2
                        best_estimator = estimator
                        best_depth = depth
                        best_split = min_split
                        best_leaf = min_leaf
                        best_criterion = criteria
    
print(f'Se ha optinido una PRECISIÓN={best_accuracy_rf:.4f}')
print(f'N_ESTIMATORS={best_estimator} - MAX_DEPTH={best_depth} - MIN_SAMPLES_SPLIT={best_split} - MIN_SAMPLES_LEAF={best_leaf} -CRITERION={best_criterion}')
# Out:
# Se ha optinido una PRECISIÓN=0.8243
# N_ESTIMATORS=13 - MAX_DEPTH=9 - MIN_SAMPLES_SPLIT=2 - MIN_SAMPLES_LEAF=1 -CRITERION=entropy

# %% [markdown]
# ---
#
# <div style='background-color:lightblue; padding:15px'><span style='color:darkblue'>
#
# (**Comentarios del Alumno - Milton Valle**)
#
#  - A partir de los primeros resultados obtenidos con el algoritmo **RandomForestClassifier**, se puede apreciar que **con los Hiperparámetros por defecto la **máxima precisión alcanzada ha sido de 0.7854**, lo cual cumple con la frontera que se nos ha solicitado del 0.75.
#
#
#  - En cambio **utilizando varios bucles FOR, y dejando que la computadora interactue sola con los mismos cinco hiperparámetros** (*uno a la vez*), se ha logrado una sustancial mejora, ya que bajo esta metodología de trabajo hemos alcanzado una **precisión de 0.8243**.
#
#
# **Siendo por lo tanto, estos últimos hiperparámetros los que llegaremos a modificar en el modelo cuanto evaluemos la precisión con el Conjunto de Prueba, en la siguiente etapa de este proyecto.**
#
#
# </span></div>
#
# ---
#
# ---
#
# | **NO**| **MODELO** | **HIPERPARAMETROS MODIFICADOS** | **PRECISION** | **OBJETIVO** | **CUMPLE** |
# |:--:|:-----:|:-------------------------:|:---------:|:--------:|:------:|
# | 1 | RandomForestClassifier | None | 0.7854 | >= 0.75 | **SI** |
# | **2** | **RandomForestClassifier** | **n_estimators=13, max_depth=9, min_samples_split=2, min_samples_leaf=1, criterion='entropy'** | **0.8243** | >= 0.75 | **SI** |
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente Trabajo Milton. Como te lo mencioné arriba, los *for anidades* son poco eficientes, pero sirven para entender la lógica detrás de los procesos de optimización o sintonización de hiperpárametros
# </div>

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# ---
#
# <span style='color:blue'>
#
# ## ETAPA 4: Comparación de Resultados entre Modelos Evaluados (*Conjunto de Prueba*)<a id=best></a>
#
# </span>

# %% [markdown]
# ---
#
#
# <span style='color:blue'>
#
# ### Calidad del Modelo - `DecisionTreeClassifier` con  Hiperparámetros Finales<a id='dt_best'></a>
#
# </span>

# %%
# Evaluar el modelo final en el conjunto de prueba
final_dt_model = DecisionTreeClassifier(max_depth=9, min_samples_split=2, min_samples_leaf=6, 
                                                                                     max_features=2, criterion='gini', random_state=12345)

# Entreno el modelo seleccionado con el Conjunto de Entrenamiento
final_dt_model.fit(X_train, y_train)

# Seguidamente realizo una  predición para lo cual utilizaré  el Conjunto de Prueba
y_test_final_pred = final_dt_model.predict(X_test)

# Finalmente evaluo la precisión ahora utilizando la predicción recién realizada y el Conjunto de Prueba
dt_test_accuracy = accuracy_score(y_test, y_test_final_pred)

print(f"La precisión obtenido con el Conjunto de Prueba y los hiperparámetros modificados, es:   PRECISION={dt_test_accuracy:.4f}")
# Out:
# La precisión obtenido con el Conjunto de Prueba y los hiperparámetros modificados, es:   PRECISION=0.7776

# %% [markdown]
# ---
#
#
# <span style='color:blue'>
#
# ### Calidad del Modelo - `RandomForestClassifier` con  Hiperparámetros Finales<a id='rf_best'></a>
#
# </span>

# %%
# Evaluar el modelo final en el conjunto de prueba
final_rf_model = RandomForestClassifier(n_estimators=13, max_depth=9, min_samples_split=2, min_samples_leaf=1, 
                                                                                             criterion='entropy', random_state=12345)

# Entreno el modelo seleccionado con el Conjunto de Entrenamiento
final_rf_model.fit(X_train, y_train)

# Seguidamente realizo una  predición para lo cual utilizaré  el Conjunto de Prueba
y_test_final_pred2 = final_rf_model.predict(X_test)

# Finalmente evaluo la precisión ahora utilizando la predicción recién realizada y el Conjunto de Prueba
rf_test_accuracy = accuracy_score(y_test, y_test_final_pred2)

print(f"La precisión obtenido con el Conjunto de Prueba y los hiperparámetros modificados, es:   PRECISION={rf_test_accuracy:.4f}")
# Out:
# La precisión obtenido con el Conjunto de Prueba y los hiperparámetros modificados, es:   PRECISION=0.8040

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ### Selección del Mejor Modelo Entrenado<a id='res_best'></a>
#
# </span>

# %% [markdown]
# ---
#
# <div style='background-color:lightblue; padding:15px'><span style='color:darkblue'>
#
# (**Comentarios del Alumno - Milton Valle**)
#
# Una vez concluida el entrenamiento de los modelos `DecisionTreeClassifier` y `RandomForestClassifier` con el **Conjunto de Prueba**, que es el restante 20% del dataset que separé y aisle del resto del proyecto hasta este punto, justamente para que ninguno de los dos modelos pueda ver y entrenarse conesa información.
#
# **A partir de la simulación de ambos modelos, con los Hiperparámetros más óptimos ajustados se ha podido ver que el modelo que ha tenido la mejor precisión durante la etapa de predicción ha sido el Modelo `RandomForestClassifier`. Por lo cual elegiré este modelo (*con sus respectivos ajustes de los Hiperparámetros obtenidos con ayuda de la computador*) para pasar a la siguiente etapa de este proyecto.**
#
#
# </span></div>
#
# ---
#
# ---
#
# | **NO**| **MODELO** | **HIPERPARAMETROS MODIFICADOS** | **PRECISION** | **OBJETIVO** | **MODELO ELEGIDO** |
# |:--:|:-----:|:-------------------------:|:---------:|:--------:|:------:|
# | 1 | DecisionTreeClassifier | max_depth=9, min_samples_split=2, min_samples_leaf=6, max_features=2, criterion='gini' | 0.7776 | >= 0.75 | NO |
# | **2** | **RandomForestClassifier** | **n_estimators=13, max_depth=9, min_samples_split=2, min_samples_leaf=1, criterion='entropy'** | **0.8040** | >= 0.75 | **SI** |
#
#
# ---
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Muy buena comparación y análisis. Seleccionaste el mejor modelo con argumentos sólidos.
# </div>

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# ---
#
# <span style='color:blue'>
#
# ## ETAPA 5: Prueba de Cordura<a id=cordura_title></a>
#
# </span>
#
# ---

# %% [markdown]
# ---
#
# <span style='color:blue'>
#
# ### Generalidades de las Pruebas de Cordura<a id='cordura1'></a>
#
# </span>

# %% [markdown]
# Las pruebas de cordura (*sanity checks*) son una técnica utilizada en machine learning para **asegurarse de que el modelo se comporte de manera razonable antes de realizar evaluaciones más profundas o implementar el modelo en un entorno de producción**. Estas pruebas no buscan medir el rendimiento final del modelo, sino asegurarse de que el modelo no esté haciendo suposiciones erróneas o tomando decisiones triviales.
#
# ---
#
# <span style='color:brown'>
#
# **¿Para qué sirven las pruebas de cordura?**
#
# </span>
#
#  1. **Verificar el comportamiento básico del modelo**: Las pruebas de cordura ayudan a garantizar que el modelo no esté tomando decisiones sin sentido o basadas en artefactos triviales en los datos.
#
#  2. **Evitar errores de implementación**: A veces, un modelo puede parecer estar funcionando bien, pero una prueba de cordura puede revelar errores de codificación o malentendidos en los datos.
#
#  3. **Validar datos y etiquetado**: También son útiles para detectar problemas en los datos, como etiquetados incorrectos o una segmentación incorrecta entre las características y las etiquetas.
#
#  4. **Prevenir resultados engañosos**: Las pruebas de cordura aseguran que un modelo no está obteniendo resultados buenos por motivos incorrectos, como una fuga de datos (*cuando el modelo tiene acceso a información que no debería durante el entrenamiento*).
#
#
# ---
#
# <span style='color:brown'>
#
# **¿Cómo se realizan las pruebas de cordura?**
#
# </span>
#
# Algunos enfoques comunes para realizar pruebas de cordura incluyen:
#
#  1. **Modelo trivial (predicción constante):**
#
#      * Se entrena un modelo trivial que hace predicciones constantes para todas las observaciones (*por ejemplo, siempre predice la clase mayoritaria o una clase aleatoria*). Si tu modelo tiene una precisión similar al de este modelo trivial, entonces algo está mal.
#
#      * **Ejemplo**: Predecir siempre la clase "0" (por ejemplo, Smart) y comparar la precisión de este modelo con la precisión del modelo entrenado.
#
#
#  2. **Entrenamiento con datos aleatorizados:**
#
#      * Se reordenan aleatoriamente las etiquetas (**`y`**) y se entrena el modelo. Si el modelo sigue obteniendo una precisión relativamente alta, podría indicar una fuga de datos o un error.
#
#      * Al entrenar con etiquetas aleatorias, el modelo no debería poder aprender ninguna relación significativa y debería obtener una precisión cercana al azar.
#
#
#  3. **Comprobación de la consistencia de las características:**
#
#      * Se puede entrenar el modelo con solo una característica aleatoria o irrelevante, y si la precisión es razonable, podría haber un problema con el conjunto de datos o el etiquetado.
#
#
#  4. **Predicción con datos vacíos o características sin sentido:**
#
#      * Se puede entrenar el modelo con datos vacíos o características irrelevantes (*como una constante*) para ver si el modelo reacciona de manera lógica.
#
#
#  5. **Cross-validation simple:**
#
#      * Realizar una validación cruzada sencilla para comprobar que el modelo no está sobreajustando o subajustando en diferentes particiones de los datos.

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ### Implementación del Modelo Trivial (*Prueba de Cordura con Predicción Constante*)<a id='cordura2'></a>
#
# </span>

# %% [markdown]
# ---
#
# <div style='background-color:lightyellow; padding:15px;'>
#
# La idea es comparar el rendimiento del modelo **`RandomForestClassifier`** con un modelo trivial que siempre predice la clase mayoritaria (*es decir, la clase más frecuente en el conjunto de entrenamiento*).
#
# Para cumplit con esta tarea tomaremos en cuenta los siguientes criterior:
#
#  * Veremos cuál es la clase mayoritaria (*por ejemplo, prediciendo siempre "Smart"*).
#
#
#  * Compararemos la precisión del RandomForestClassifier con la precisión del modelo trivial.
#
# </div>
#
# ---

# %%
# Verificamos la clase mayoritaria en el conjunto de entrenamiento
majority_class = y_train.mode()[0]

# Creamos un modelo trivial que siempre prediga la clase mayoritaria
y_val_pred_trivial = [majority_class] * len(y_valid)

# Calcular la precisión del modelo trivial en el conjunto de validación
trivial_accuracy = accuracy_score(y_valid, y_val_pred_trivial)

# Calcular la precisión del modelo RandomForestClassifier en el conjunto de validación
rf_val_accuracy = accuracy_score(y_valid, final_rf_model.predict(X_valid))

print(f'Modelo Trivial: {trivial_accuracy:.4f}   -   RandomForestClassifier: { rf_val_accuracy:.4f}')
# Out:
# Modelo Trivial: 0.6843   -   RandomForestClassifier: 0.8243

# %% [markdown]
# ---
#
# <div style='background-color:lightblue; padding:15px'><span style='color:darkblue'>
#
# (**Comentarios del Alumno - Milton Valle**)
#
# La prueba de cordura con el `modelo trivial` y el `RandomForestClassifier` arrojó los siguientes resultados:
#
#  * El **Modelo Trivial** ha alcanzado (prediciendo siempre la clase mayoritaria) un valor de **`0.6843`** de precisión.
#
#  * El modelo **RandomForestClassifier** ha alcanzado un valor de **`0.8243`** de precisión en el conjunto de validación.
#
#
#
# Esto nos indica que el modelo `RandomForestClassifier` **está aprendiendo de manera efectiva**, ya que su precisión es significativamente superior a la de un modelo trivial.  **El modelo no está tomando decisiones triviales y está capturando patrones en los datos**.
#
#
# </span></div>
#
#
# ---

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ### Entrenamiento con Etiquetas Aleatorizadas<a id='cordura3'></a>
#
# </span>

# %% [markdown]
# ---
#
# <div style='background-color:lightyellow; padding:15px;'>
#
# Evaluar con etiquetas aleatorias es otra prueba de cordura muy útil para asegurarse de que el modelo no está aprendiendo patrones "falsos" o aprovechándose de alguna fuga de datos. La idea principal es la siguiente:
#
#  * Cuando aleatorizamos las etiquetas (**`y`**), eliminamos la relación entre las características (**`X`**) y las etiquetas. Si el modelo sigue logrando una precisión alta en este escenario, podría haber un problema de fuga de información o el modelo podría estar sobreajustado.
#
# Para cumplir con este objetivo cumpliremos con el siguiente procedimiento:
#
#  1. **Aleatorizar las etiquetas**: Se toma la variable objetivo (**`y`**) y se desordena aleatoriamente, manteniendo las mismas características (**`X`**).
#
#
#  2. **Entrenar el modelo con etiquetas aleatorias**: Entrenamos el modelo con las etiquetas desordenadas.
#
#
#  3. **Evaluar la precisión**: Si el modelo obtiene una precisión significativamente alta con las etiquetas aleatorias, podría indicar un problema con el modelo o los datos.
#
#
# **`El modelo debería lograr una precisión cercana al azar si está funcionando correctamente`**.
#
# </div>
#
# ---

# %%
# Aleatorizar las etiquetas del conjunto de entrenamiento
import numpy as np

y_train_random = np.random.permutation(y_train)

# Entrenar el modelo de RandomForestClassifier con las etiquetas aleatorias
rf_model_random_labels = RandomForestClassifier(n_estimators=200, max_depth=10, min_samples_split=9, random_state=12345)
rf_model_random_labels.fit(X_train, y_train_random)

# Evaluar la precisión del modelo con etiquetas aleatorias en el conjunto de validación
y_val_pred_random = rf_model_random_labels.predict(X_valid)
random_labels_accuracy = accuracy_score(y_valid, y_val_pred_random)

print(f'Precisión del modelo RandomForestClassifier (entrenado con etiquetas aleatorias): { random_labels_accuracy:.4f}')
# Out:
# Precisión del modelo RandomForestClassifier (entrenado con etiquetas aleatorias): 0.6858

# %% [markdown]
# ---
#
# <div style='background-color:lightblue; padding:15px'><span style='color:darkblue'>
#
# (**Comentarios del Alumno - Milton Valle**)
#
# El modelo de `RandomForestClassifier` entrenado con etiquetas aleatorias ha alcanzado  una **precisión de 0.6952 en el conjunto de validación**. Esto está cerca de una predicción al azar (*similar al modelo trivial*), lo cual es esperable en una situación donde no hay relación entre las características y las etiquetas.
#
#
# **El resultado obtenido sugiere que el modelo no está aprovechando ninguna fuga de datos y no está aprendiendo patrones falsos cuando las etiquetas no tienen relación con las características, lo que es un buen indicio**.
#
#
# </span></div>
#
#
# ---

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ### Comprobación de la Consistencia de las Características<a id='cordura4'></a>
#
# </span>

# %% [markdown]
# ---
#
# <div style='background-color:lightyellow; padding:15px;'>
#
# La prueba de cordura denominada **comprobación de la consistencia de las características** tiene como objetivo asegurarse de que el modelo esté utilizando de manera efectiva las características relevantes en los datos. El procedimiento es el siguiente:
#
# Esta prueba se utiliza para **verificar si el modelo realmente está capturando patrones significativos en los datos o si está basando sus predicciones en características triviales o irrelevantes**.
#
#
# Nuestro procedimiento de trabajo  se detalla a continuación:
#
#
#  1. **Seleccionar una característica irrelevante o constante**: Se puede entrenar el modelo utilizando una característica irrelevante (*o incluso con datos constantes*).
#
#
#  2. **Evaluar el rendimiento del modelo**: Si el modelo obtiene una precisión alta utilizando características irrelevantes, entonces hay un problema.
#
#
#  3. **Interpretación**: Un rendimiento bajo sería esperable, ya que las características irrelevantes no deberían permitirle al modelo realizar predicciones útiles.
#
#
#
# </div>
#
# ---

# %%
# Generar un conjunto de características irrelevantes (constantes)
X_train_irrelevant = np.full_like(X_train, fill_value=0)  # Llenar todas las características con 0
X_val_irrelevant = np.full_like(X_valid, fill_value=0)

# Entrenar el modelo de RandomForestClassifier con las características irrelevantes
rf_model_irrelevant = RandomForestClassifier(n_estimators=200, max_depth=10, min_samples_split=9, random_state=12345)
rf_model_irrelevant.fit(X_train_irrelevant, y_train)

# Evaluar la precisión del modelo con características irrelevantes en el conjunto de validación
y_val_pred_irrelevant = rf_model_irrelevant.predict(X_val_irrelevant)
irrelevant_features_accuracy = accuracy_score(y_valid, y_val_pred_irrelevant)

print(f'Precisión del modelo RandomForestClassifier (entrenado con Características Irrelevantes): {irrelevant_features_accuracy:.4f}')
# Out:
# Precisión del modelo RandomForestClassifier (entrenado con Características Irrelevantes): 0.6843

# %% [markdown]
# ---
#
# <div style='background-color:lightblue; padding:15px'><span style='color:darkblue'>
#
# (**Comentarios del Alumno - Milton Valle**)
#
# El modelo de `RandomForestClassifier` **entrenado con características irrelevantes** (*constantes*) obtuvo una precisión de 0.6843, que es similar a lo que esperaríamos de un Modelo Trivial o al azar.
#
# Este resultado es consistente con lo que debería suceder, ya que las características irrelevantes no deberían permitirle al modelo hacer predicciones útiles.
#
# **La baja precisión confirma que el modelo no está basando sus predicciones en información sin sentido, lo cual es un buen indicador de que está utilizando las características correctas en los datos reales.**
#
#
# </span></div>
#
#
# ---

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ### Predicción con Datos Vacíos o Características Sin Sentido<a id='cordura5'></a>
#
# </span>

# %% [markdown]
# ---
#
# <div style='background-color:lightyellow; padding:15px;'>
#
# El objetivo de esta prueba es verificar si el modelo es robusto y no está reaccionando de manera significativa a datos vacíos o sin sentido. **En esta prueba, entrenamos el modelo con datos vacíos** (*es decir, con valores como ceros o aleatorios irrelevantes*) o con características irrelevantes, para comprobar que el modelo no haga predicciones útiles en este escenario.
#
# Los pasos que debemos seguir para su correcta implementación son:
#
#
#  1. **Generar datos vacíos o sin sentido**: Reemplazaremos los valores de las características por ceros o valores aleatorios irrelevantes.
#
#
#  2. **Entrenar el modelo**: Entrenamos el `RandomForestClassifier` con estos datos vacíos o sin sentido.
#
#
#  3. **Evaluar el rendimiento**: Si el modelo obtiene una precisión baja (*cerca del azar*), significa que no está haciendo uso de información útil de las características irrelevantes.
#
#
# Los resultados obtenidos los debermos interpretar segùn el siguiente criterio:
#
#  * **Baja precisión**: Esto indicaría que el modelo no está haciendo predicciones útiles, lo cual es lo esperado. No debería poder hacer buenas predicciones con datos irrelevantes.
#
#
#  * **Alta precisión**: Si la precisión es alta, podría ser una señal de que el modelo está sobreajustando o hay una fuga de datos.
#
#
# </div>
#
# ---

# %%
# Generar datos vacíos (rellenados con ceros)
X_train_empty = np.zeros_like(X_train)  # Conjunto de entrenamiento lleno de ceros
X_val_empty = np.zeros_like(X_valid)  # Conjunto de validación lleno de ceros

# Entrenar el modelo de RandomForestClassifier con los datos vacíos
rf_model_empty = RandomForestClassifier(n_estimators=200, max_depth=10, min_samples_split=9, random_state=12345)
rf_model_empty.fit(X_train_empty, y_train)

# Evaluar la precisión del modelo con los datos vacíos en el conjunto de validación
y_val_pred_empty = rf_model_empty.predict(X_val_empty)
empty_features_accuracy = accuracy_score(y_valid, y_val_pred_empty)

print(f'Precisión del modelo RandomForestClassifier (entrenado con Datos Vacíos): {empty_features_accuracy:.4f}')
# Out:
# Precisión del modelo RandomForestClassifier (entrenado con Datos Vacíos): 0.6843

# %% [markdown]
# ---
#
# <div style='background-color:lightblue; padding:15px'><span style='color:darkblue'>
#
# (**Comentarios del Alumno - Milton Valle**)
#
# El modelo de `RandomForestClassifier` entrenado con **datos vacíos** (*rellenados con ceros*) alcanzó una **precisión de 0.6843**, lo cual es similar a lo esperado en predicciones al azar o triviales.
#
# **Este resultado es positivo**, ya que confirma que el modelo no está extrayendo información útil de datos vacíos o irrelevantes. Es una señal de que el modelo está utilizando correctamente las características cuando se le proporcionan datos significativos.
#
# </span></div>
#
#
# ---

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# <span style='color:blue'>
#
# ### Validación Cruzada<a id='cordura6'></a>
#
# </span>

# %% [markdown]
# ---
#
# <div style='background-color:lightyellow; padding:15px;'>
#
# La validación cruzada es una técnica utilizada para evaluar el rendimiento de un modelo de manera más robusta al entrenarlo y evaluarlo en diferentes particiones del conjunto de datos. **Es una prueba de cordura útil para verificar que el modelo no está sobreajustado o subajustado a una única partición de los datos**.
#
# Para su implementación los pasos a seguir son los que se detallan a continuación:
#
#  1. **Dividir los datos**: En la validación cruzada, los datos se dividen en varios subconjuntos. **El modelo se entrena en un subconjunto y se evalúa en otro**. Este proceso se repite hasta que todos los subconjuntos hayan sido utilizados como conjunto de validación al menos una vez.
#
#
#  2. **Entrenar y evaluar el modelo**: Entrenamos el modelo de `RandomForestClassifier` en cada subconjunto y calculamos la precisión media a través de todos los subconjuntos.
#
#
#  3. **Interpretación**:
#
#     - **Alta consistencia entre subconjuntos**: Si las puntuaciones de precisión son consistentes entre los diferentes subconjuntos, esto indica que el modelo generaliza bien.
#
#     - **Variabilidad alta entre subconjuntos**: Si hay una alta variabilidad en la precisión entre diferentes subconjuntos, el modelo podría estar sobreajustado o subajustado.
#
#
# **`Consideraciones para su Implementación`**:
#
# Vamos a implementar la validación cruzada utilizando 5 "folds". Esto significa que los datos se dividirán en 5 subconjuntos, y en cada iteración, 4 subconjuntos se usarán para entrenar y el subconjunto restante para validar. Al final, tomaremos la media de las precisiones obtenidas.
#
# </div>
#
# ---

# %%
from sklearn.model_selection import cross_val_score

# Entrenar el modelo de RandomForestClassifier utilizando validación cruzada (5 folds)
rf_model_cv = RandomForestClassifier(n_estimators=200, max_depth=10, min_samples_split=9, random_state=12345)

# Aplicar validación cruzada
cv_scores = cross_val_score(rf_model_cv, X_train, y_train, cv=5, scoring='accuracy')

# Calcular la precisión promedio y la desviación estándar
cv_mean_accuracy = np.mean(cv_scores)
cv_std_deviation = np.std(cv_scores)

print(f"Precisión Promedio: {cv_mean_accuracy:.4f}   -   Desviación Estándar: {cv_std_deviation:.4f}")
# Out:
# Precisión Promedio: 0.8237   -   Desviación Estándar: 0.0084

# %% [markdown]
# ---
#
# <div style='background-color:lightblue; padding:15px'><span style='color:darkblue'>
#
# (**Comentarios del Alumno - Milton Valle**)
#
# El modelo de `RandomForestClassifier` con validación cruzada de 5 "folds" alcanzó una **precisión promedio de 0.8237** y  una **desviación estándar de 0.0084**.
#
# El valor de la `Precisión Promedio` indica que el modelo tiene un rendimiento consistente, con un valor cercano a lo obtenido en las pruebas anteriores.
#
#
# Por otro lado el valor de la `Desviación Estándar` es bastante baja (0.0084) sugiere que el modelo no está sobreajustado ni subajustado, y su rendimiento es bastante consistente a través de las diferentes particiones del conjunto de datos.
#
# **Este resultado muestra que el modelo es robusto y generaliza bien en diferentes subconjuntos de los datos**.
#
# </span></div>
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Increíble desarrollo de la prueba de cordura, has llevado tu proyecto a un nivel superlativo. Felicitaciones 🤯
# </div>

# %% [markdown]
# ---
#
# [Volver a Contenido](#back)
#
# ---

# %% [markdown]
# ---
#
# <span style='color:blue'>
#
# ## ETAPA 6: Comentarios Finales del Proyecto<a id=end></a>
#
# </span>
#
# ---

# %% [markdown]
# ---
#
# <div style='background-color:rgba(12, 120, 210, 0.15); padding:15px'><span style='color:darkblue'>
#
# (**Comentarios del Alumno - Milton Valle**)
#
#  1. Una vez descargado el dataset he procedido a crear un DataFrame el cual ha sido utilizado inicialmente para revisar las características de la información, también revisé si existian valores ausentes y duplicados dentro de este DataFrame. Sin embargo el DataFrame se encontraba limpio.
#
#
#  2. Seguidamente he realizado unas gráficas de **histogramas** para poder verificar si existían sesgos en los datos, **boxplots** para poder ver si es que existían valores atípicos, **pairplots** y una **matriz de correlación** con la finalidad de poder encontrar correlaciones entre las diferentes columnas de datos. Todo esto ha sido realizado con la única idea de poder comprender mejor la información.
#
#
#  3. Luego en la Etapa 2, he procedido a segmentar el dataset principal del proyecto en 60% para el Conjunto de Entrenamiento, 20% para el Conjunto de Validación y un 20% para el Conjunto de Prueba. para realizar esta tarea he utilizado la función `train_test_split` del modulo `model_selection`.
#
#
#  4. A continuación en la Etapa 3 he procedido a entrenar los modelos `DecisionTreeClassifier` y `RandomForestClassifier`. Durante la realización de los ajustes de los hiperparámetros, he dividido esta tarea en dos grupos principales de trabajo:
#
#      * El primer grupo consistía en realizar el ajuste de los hiperparámetor uno a uno y a partir de la selección del ajuste más óptimo pasaba al siguiente hiperparámetro, pero manteniendo el ajuste del hiperparámetro ajustado previamente. Y así sucesivamente hasta concluir con todos los hiperparámetros que he seleccionado para ajustar.
#
#      * El segundo grupo de trabajo consistía en construir bucles FOR anidados con 4 niveles para el modelo `DecisionTreeClassifier` y con 5 niveles para el modelo `RandomForestClassifier`. Con la realización de esta tarea he confirmado que este es el mejor modo de realizar el ajuste de los hiperparámetros de cada modelo, ya que me ayudaron a obtener el valor de precisión más alto dentro de todo el grupo.
#
#
#  5. He podido apreciar también que entre los modelos `DecisionTreeClassifier` y `RandomForestClassifier` el que mayor precisión nos ayuda a obtener el este último. Según la bibliografía consultada en internet dice que este hecho se debe a que por un lado el modelo `RandomForestClassifier` es un modelo más avanzado que ´DecisionTreeClassifier`, y en segundo lugar que el modelo `RandomForestClassifier es un modelo que trabaja de manera paralela con múltiples modelos `DecisionTreeClassifier` lo cual le ayuda a conseguir mejores resultados de precisión y a la vez evita que este modelo se sobreajuste.
#
#
#  6. Una vez seleccionado el modelo que más precisión me ha brindado, he procedido a indagar en internet acerca de las pruebas de cordura que puedo realizar en el modelo `RandomForestClassifier´, siendo en total cinco tipos de pruebas de cordura que me son posibles realizar, a continuación detallo las mismas, junto con sus resultados obtenidos:
#
#     * **`Modelo Trivial`**: La idea es comparar el rendimiento del modelo RandomForestClassifier con un modelo trivial que siempre predice la clase mayoritaria (*es decir, la clase más frecuente en el conjunto de entrenamiento*). El **Modelo Trivial** ha alcanzado un **valor de 0.6843 de precisión**. **Esto nos indica que el modelo RandomForestClassifier está aprendiendo de manera efectiva, ya que su precisión es significativamente superior a la de un modelo trivial. El modelo no está tomando decisiones triviales y está capturando patrones en los datos.
#
#     *  **`Entrenamiento con Etiquetas Aleatorizadas`**: Evaluar con etiquetas aleatorias es otra prueba de cordura muy útil para asegurarse de que el modelo no está aprendiendo patrones "falsos" o aprovechándose de alguna fuga de datos. El modelo entrenado con etiquetas aleatorias ha alcanzado una **precisión de 0.6952** en el conjunto de validación. Esto está cerca de una predicción al azar (similar al modelo trivial), lo cual es esperable en una situación donde no hay relación entre las características y las etiquetas. El resultado obtenido sugiere que **el modelo no está aprovechando ninguna fuga de datos y no está aprendiendo patrones falsos cuando las etiquetas no tienen relación con las características**, lo que es un buen indicio.
#
#     * **`Comprobación de la Consistencia de las Características`**: Esta prueba **se utiliza para verificar si el modelo realmente está capturando patrones significativos en los datos o si está basando sus predicciones en características triviales o irrelevantes**. El modelo elaborado ha obtenido una **precisión del 0.6843**, La baja precisión confirma que el modelo no está basando sus predicciones en información sin sentido, lo cual es un buen indicador de que está utilizando las características correctas en los datos reales.
#
#     * **`Predicción con Datos Vacíos`**: En esta prueba, entrenamos el modelo con datos vacíos o con características irrelevantes, para comprobar que el modelo no haga predicciones útiles en este escenario. Este modelo ha alcanzado una **precisión de 0.6843**. Este resultado es positivo, ya que confirma que el modelo no está extrayendo información útil de datos vacíos o irrelevantes. Es una señal de que el modelo está utilizando correctamente las características cuando se le proporcionan datos significativos.
#
#     * **`Validación Cruzada`**: La validación cruzada es una técnica utilizada para evaluar el rendimiento de un modelo de manera más robusta al entrenarlo y evaluarlo en diferentes particiones del conjunto de datos. **Es una prueba de cordura útil para verificar que el modelo no está sobreajustado o subajustado a una única partición de los datos**. El modelo con validación cruzada alcanzó una **precisión de 0.8237** y una **Desviación Estándar de 0.0084**. El `valor de la Precisión Promedio` indica que el modelo tiene un rendimiento consistente, con un valor cercano a lo obtenido en las pruebas anteriores. Por otro lado el `valor de la Desviación Estándar` es bastante baja (0.0084) sugiere que el modelo no está sobreajustado ni subajustado, y su rendimiento es bastante consistente a través de las diferentes particiones del conjunto de datos.
#
#
# </span></div>
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario General del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Miltón, tu dedicación y habilidad en este proyecto son verdaderamente notables. Has cumplido con todos los objetivos propuestos y, lo que es más impresionante, has llevado el trabajo más allá por iniciativa propia, demostrando un nivel de compromiso excepcional. La estructura y organización de tu notebook son ejemplares, lo que facilita la comprensión de tu proceso de análisis. Tus apreciaciones y análisis no solo son correctos, sino que están sólidamente respaldados por la información obtenida en cada sección, lo cual refleja un trabajo meticuloso y bien fundamentado. Es particularmente llamativo cómo te cuestionas a ti mismo en varias etapas del proyecto, evidenciando un profundo dominio y entendimiento de los temas abordados. Este nivel de reflexión crítica es una cualidad valiosa en un científico de datos. Miltón, has creado un proyecto que puede considerarse ejemplar en muchos aspectos. Continúa nutriendo esta combinación de habilidades técnicas, pensamiento crítico y iniciativa propia. Con este enfoque, estás bien encaminado para destacar en tu carrera. ¡Sigue adelante con este excelente trabajo!✅
# </div>
